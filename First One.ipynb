# %%
locationlist = [1,2,3,4,5,6,11,12,13,14,15,16,21,22,23,24,25,26]
statusreport = 'not'
inventory = set()
currentlocation = 15
listofactions = {'look','take','talk','leave','inventory'}
currentlook = ''
currenttalk = ''
currentinteract = ''
movemeter = 0
npclist = {'baker', 'blacksmisth', 'fatboy'}
cakeingred = {'flour','sugar','milk','buter'}
smithingred = set() 
bakeringred = set()
keyingred = {'copper', 'lead', 'iron'}
fatboycounter = 0
level = 0
level2 = 1
level3 = 1
continuetalk = 'y'
giveinvent = set()
giveboy = ''
giveboyq = ''
keytimer = 0
false = ['n', 'nothing', 'not', 'no', 'false']




#Descriptions for each of the areas
area1 = "There doesn't seem to be anything here"
area2 = "There is an old man sitting on a chair"
area3 = "You see a bottle of milk on the ground"
area4 = "You see an oven with a woman standing next to it"
area5 = "There doesn't seem to be anything here"
area6 = "You see a Gate"
area11 = "You see a bag of flour on the ground"
area12 = "You see a bag of sugar on the gorund"
area13 = "You see a fat boy holding a block of gold"
area14 = "There doesn't seem to be anything here"
area15 = "You see a blacksmith standing by a forge"
area16 = "There doesn't seem to be anything here"
area21 = "You see a block of copper on the ground"
area22 = "You see a stick of butter on the ground"
area23 = "There doesn't seem to be anything here"
area24 = "You see a block of iron on the ground"
area25 = "There doesn't seem to be anything here"
area26 = "You see a cat"

#description for alternate areas
alt1area13 = "You see a fat boy eating cake"

listofareas = [area1,area2,area3,area4,area5,area6,area11,area12,area13,area14,area15,area16,area21,area22,area23,area24,area25,area26] 

#Making Dictionary for look
lookdict = {}
i = 0
for number in locationlist:
    lookdict[number] = listofareas[i]
    i+=1
purelookdict = lookdict
    
#Spelling out What is in each location
takearea1 = []
takearea2 = []
takearea3 = ['milk']
takearea4 = []
takearea5 = []
takearea6 = []
takearea11 = ['flour']
takearea12 = ['sugar']
takearea13 = ['gold']
takearea14 = []
takearea15 = []
takearea16 = []
takearea21 = ['copper']
takearea22 = ['buter']
takearea23 = []
takearea24 = ['iron']
takearea25 = []
takearea26 = ['cat']

listofthings = [takearea1,takearea2,takearea3,takearea4,takearea5,takearea6,takearea11,takearea12,takearea13,takearea14,takearea15,takearea16,takearea21,takearea22,takearea23,takearea24,takearea25,takearea26]
    
#Making Dictionary for take
takedict = {}
i = 0
for number in locationlist:
    takedict[number] = listofthings[i]
    i+=1
puretakedict = takedict

    #Spelling out which people to talk to in areas
talkarea1 = ['']
talkarea2 = ['']
talkarea3 = ['']
talkarea4 = ['baker']
talkarea5 = ['']
talkarea6 = ['']
talkarea11 = ['']
talkarea12 = ['']
talkarea13 = ['fatboy']
talkarea14 = ['']
talkarea15 = ['blacksmith']
talkarea16 = ['']
talkarea21 = ['']
talkarea22 = ['']
talkarea23 = ['']
talkarea24 = ['']
talkarea25 = ['']
talkarea26 = ['cat']

listofpeople = [talkarea1,talkarea2,talkarea3,talkarea4,talkarea5,talkarea6,talkarea11,talkarea12,talkarea13,talkarea14,talkarea15,talkarea16,talkarea21,talkarea22,talkarea23,talkarea24,talkarea25,talkarea26,]

#Making Dictionary for choices of who to talk to

whotalkdict = {}
i = 0
for number in locationlist:
    whotalkdict[number] = listofpeople[i]
    i+=1




#Way for people to respond

#BAKER
a = bakertalk0a = 'Hello, I can cook something for you if you have the right ingrediants'
s = bakertalk1b = 'Do you have any ingrediants for me?'
d = bakertalk2a = "Looks like I have enough ingrediants for me to bake a cake. It'll be ready in just a few moments"
f = bakertalk3a = "Here, enjoy your cake"
g = bakertalk4a = "I still need 3 more ingrediants to make anything"
h = bakertalk5a = "I still need 2 more ingrediants to make anything"
j = bakertalk6a = "I still need 1 more ingrediant to make anything"

bakelist = [a,s,d,f,g,h,j]

bakerresponsedict = {}
for i in range(0,7):
    bakedictstring = 'BAKER: ', bakelist[i]
    bakerresponsedict[i] = bakedictstring

###bakerresponsedict = {0:bakertalk0a, 1:bakertalk1b, 2:bakertalk2a, 3:bakertalk3a, 4:bakertalk4a, 5:bakertalk5a, 6:bakertalk6a}



#FATBOY:
a = boytalk0b = "Go away, I don't want to talk to you"
s = boytalk1b = "Dang yo, you're so annoying! What the heck do you want?"
d = boytalk2b = "Bro no way! I'm not giving you this gold for anything...well almost anything, but still, you're not geting this gold"
f = boytalk3b = "Whoa, you have a cake? I'll give you my peice of gold for that cake"
g = boytalk4a = "Alright, I gave you the gold, now go away so I can enjoy my cake"
h = boytalk5a = "Man, I don't even have whatever you're talking about "
j = boytalk6a = "I told you you're not getting this gold unless you got something real valueable!"
k = boytalk7a = "No way!, my gold is way more valuable than", giveboy

boylist = [a,s,d,f,g,h,j,k]

boyresponsedict = {}

for i in range(0,8):
    boydictstring = 'FATBOY: ', boylist[i]
    boyresponsedict[i] = boydictstring

#BLACKSMITH
a = smithtalk0 = "Hello! I can forge anything with the right materials"
s = smithtalk1 = "What would you like me to forge?"
d = smithtalk2 = "Hmm, in order to forge a key, I'm gonna need 3 different types of metals"
f = smithtalk3 = "Do you have any more metal for me?"
g = smithtalk4 = "I still need 3 more types of metal"
h = smithtalk5 = "I still need 2 more types of metal"
j = smithtalk6 = "I still need 1 more type of metal"
k = smithtalk7 = "Great! I have all the materials I need to make a key, now I just need the payment"
l = smithtalk8 = "No way, that's not gonna be enough to compensate me"
z = smithtalk9 = "Perfect! I'll have your key ready in no time."
x = smithtalk10 = "I'm not quite done with your key yet. Come back in a little while"
c = smithtalk11 = "That ingrediant isn't useful in making a key"
v = smithtalk12 = "Your key is finished. Here it is"

smithlist = [a,s,d,f,g,h,j,k,l,z,x,c,v]
smithresponsedict = {}
for i in range (0,13):
    smithdictstring = 'BLACKSMITH: ' + smithlist[i]
    smithresponsedict[i] = smithdictstring
    
#Talking function

def response(person):
    global level
    global level2
    global level3
    global fatboycounter
    global inventory
    global giveboy
    global giveboyq
    global currentlocation
    global takedict
    global lookdict
    global puretakedict
    global purelookdict
    global defwhile
    global keytimer
    global continuetalk
    global false
    defwhile = 0
    #BAKER RESPONSE
    if person == 'baker':
        global giveinvent
        global bakeringred
        if level == 0:
            print (bakerresponsedict[0])
            level = 1
            response('baker')
        elif len(bakeringred) == 3:
            print (bakerresponsedict[2])
            print ('.')
            print ('.')
            print ('.')
            print (bakerresponsedict[3])
            inventory.add('cake')
            bakeringred = {}
        else:
            count = len(bakeringred) + 4
            print (bakerresponsedict[count])
            if len(inventory) != 0:
                while defwhile == 0:
                    if 'nothing' not in giveinvent:
                        giveinvent = inventory
                        giveinvent.add('nothing')
                    print (bakerresponsedict[1])
                    givestring = ('What would you like to give to the baker?', inventory)
                    give = input(givestring)
                    if give == 'nothing':
                        defwhile = 1
                    elif give in giveinvent:
                        if give in cakeingred:
                            bakeringred.add(give)
                            defwhile = 1
                            inventory.remove(give)
                        else:
                            print("Baker: That ingrediant just won't work")
                    else:
                        print('You do not have any', give)
            else:
                print('but it seems like you have nothing in your inventory to give')
    
    #FATBOY RESPONSE
    if person == 'fatboy':
        if level2 == 1:
            print(boyresponsedict[0])
            fatboycounter += 1
            if fatboycounter == 7:
                level2 = 2
        elif level2 == 2:
            print(boyresponsedict[1])
            responser = input()
            if responser == 'gold':
                print (boyresponsedict[2])
                level2 = 3
            else:
                print(boyresponsedict[5])
        elif level2 == 3:
            print (boyresponsedict[6])
            giveboyq = input('do you have anything to show to the fatboy? (y/n)')
            if giveboyq == 'y':
                giveboy = input(inventory)
                if giveboy in inventory:
                    while defwhile == 0:
                        if giveboy == 'cake':
                            print (boyresponsedict[3])
                            answer = input("Give the cake to fatboy? (y/n)")
                            if answer == 'y':
                                boyresponsedict[4]
                                inventory.remove('cake')
                                area13 = alt1area13
                                inventory.add('gold')
                            
                                defwhile = 1
                            elif answer == 'n':
                                print("The Fatboy suddenly punches you in the face")
                                inventory = set()
                                currentlocation = 1
                                lookdict = purelookdict
                                takedict = puretakedict
                                defwhile = 1
                            else:
                                print('invalid command')
                                defwhile = 0
                        else:
                            print(boyresponsedict[7])
                else:
                    print("You don't have", giveboy, "in your inventory")
      
    defwhile = 0
    
    #BLACKSMITH
    if person == 'blacksmith':
        if level3 == 1:
            print(smithresponsedict[0])
            level3 = 2
            response('blacksmith')
        elif level3 == 2:
            print(smithresponsedict[1])
            forge = input()
            if forge == 'key':
                print(smithresponsedict[2])
                level3 = 3
            elif forge in false:
                continuetalk = 'n'
            else:
                print("I'm sorry, I can't forge a(n)", forge)
        elif level3 == 3:
            print(smithresponsedict[3])
            answersmith = input(inventory)
            if answersmith in inventory:
                if answersmith in keyingred:
                    inventory.remove(answersmith)
                    smithingred.add(answersmith)
                    print('BLACKSMITH: Great')
                    if len(smithingred) == 0:
                        print(smithresponsedict[4])
                    elif len(smithingred) == 1:
                        print(smithresponsedict[5])
                    elif len(smithingred) == 2:
                        print(smithresponsedict[6])
                else:
                    print(smithresponsedict[11])
            elif answersmith == 'no':
                continuetalk = 'n'
            else:
                print('That is not in your inventory')
            if len(smithingred) == 3:
                level3 = 4
        elif level3 == 4:
            print(smithresponsedict[7])
            payment = input(inventory)
            if payment in inventory:
                if payment == 'gold':
                    inventory.remove('gold')
                    print(smithresponsedict[9])
                    level3 = 5
                    keytimer = 1
                else:
                    print(smithresponsedict[8])
            else:
                print("You don't have", payment, "in your inventory")
        elif level3 == 5:
            if keytimer == 2:
                inventory.add('key')
                print(smithresponsedict[12])
                
            else:
                print(smithresponsedict[10])
a = smithtalk0 = "Hello! I can forge anything with the right materials"
s = smithtalk1 = "What would you like me to forge?"
d = smithtalk2 = "Hmm, in order to forge a key, I'm gonna need 3 different types of metals"
f = smithtalk3 = "Do you have any more metal for me?"
g = smithtalk4 = "I still need 3 more types of metal"
h = smithtalk5 = "I still need 2 more types of metal"
j = smithtalk6 = "I still need 1 more type of metal"
k = smithtalk7 = "Great! I have all the materials I need to make a key, now I just need the payment"
l = smithtalk8 = "No way, that's not gonna be enough to compensate me"
z = smithtalk9 = "Perfect! I'll have your key ready in no time."
x = smithtalk10 = "I'm not quite done with your key yet. Come back in a little while"
c = smithtalk11 = "That ingrediant isn't useful in making a key"
v = smithtalk12 = "Your key is finished. Here it is"
            
            
            
        

        
        
            
            


            
            

        
    
        
       
    
    





while statusreport == 'not':
    continuetalk = 'y'
    currentlook = lookdict[currentlocation]
    currenttalk = whotalkdict[currentlocation]
    currenttake = takedict[currentlocation]
    if movemeter == 0:
        print ('You are currently in',currentlocation)
    movemeter = 1
    action = input ('Say an action: ')

#HELP

    if action == 'help':
        print ('Choose from the following actions:', listofactions)

#LOOK 

    elif action == 'look':
        print(currentlook)

#TALK
        
    elif action == 'talk':
        if currenttalk == ['']:
            print ('There is no one to talk to...')
        else:
            inputquestion = ('Choose who to talk to ' + str(currenttalk))
            talkto = input (inputquestion)
            if talkto in currenttalk:
                response(talkto)
                while continuetalk == 'y':
                    continuetalk = input('Talk again?(y/n)')
                    if continuetalk == 'y':
                        print(response(talkto))
                    else: 
                        fatboycounter = 0             
            else: 
                print('invalid command')

#LEAVE                
                
    elif action == 'leave':
        leavedirection = input('Which way would you like to go? (N,S,E,W)')
        if leavedirection == 'w':
            if currentlocation in [1,11,21]:
                print ('You cannot move any further West.')
            else:
                currentlocation -= 1
                movemeter = 0
        elif leavedirection == 'n':
            if currentlocation in [1,2,3,4,5,6]:
                print ('You cannot move any further North.')
            else:
                currentlocation -= 10
                movemeter = 0
        elif leavedirection == 's':
            if currentlocation in [21,22,23,24,25,26]:
                print ('You cannot move any further South.')
            else:
                currentlocation += 10
                movemeter = 0
        elif leavedirection == 'e':
            if currentlocation in [6,16,26]:
                print ('You cannot move any further East.')
            else:
                currentlocation += 1
                movemeter = 0
        else:
            print('That is not a direction')
        if keytimer == 1:
            keytimer = 2
                
#TAKE

    elif action == 'take':
        tempcurrenttake = currenttake
        if 'nothing' not in tempcurrenttake:
            tempcurrenttake.append('nothing') 
        takestring = 'what would you like to take? ',tempcurrenttake
        objecttake = input (takestring)
        if objecttake in currenttake:
            if objecttake == 'nothing':
                axaq = 1
            elif objecttake == 'gold':
                print("You try to take the gold from the fatboy, but he punches you unconscious")
                inventory = set()
                currentlocation = 1
                lookdict = purelookdict
                takedict = puretakedict
            elif objecttake == 'cat':
                takedict[26] = ['lead']
                whotalkdict[26] = [''] 
                lookdict[26] = 'There seems to be a block of lead sitting where the cat used to be'
                print('The cat ran away before you could catch it')
            else:
                inventory.add(objecttake)
                print(objecttake, 'was added to your inventory')
                lookdict[currentlocation] = "There doesn't seem to be anything here"
                currenttake.remove(objecttake)
            
        else: 
            print("There is no", "'", objecttake, "'", "around")

#INVENTORY                
                
    elif action == 'inventory':
        print(inventory)
#QUIT    
    elif action == 'quit':
        statusreport = 'quit'
#INVALID COMMAND        
    else:
        print('invalid command')
        
        
        
if statusreport == 'quit':
    print('Congratualtions quitter, you lose')
# Out:
# You are currently in 15
# Say an action: leave
# Which way would you like to go? (N,S,E,W)s
# You are currently in 25
# Say an action: leave
# Which way would you like to go? (N,S,E,W)e
# You are currently in 26
# Say an action: take
# ('what would you like to take? ', ['cat', 'nothing'])cat
# The cat ran away before you could catch it
# Say an action: look
# There seems to be a block of lead sitting where the cat used to be
# Say an action: talk
# There is no one to talk to...
# Say an action: take
# ('what would you like to take? ', ['lead', 'nothing'])lead
# lead was added to your inventory
# Say an action: quit
# Congratualtions quitter, you lose

# %%
dictt = {}
listt = ['w','x','a']
iny = 0
loc = [1,2,3]
for i in loc:
    dictt[i] = listt[iny]
    iny+=1
dictt[1]

# %%
aaa = 'red'
bbb = 'green'
bera = [aaa,bbb]
bera

# %%
testt = 1
def resp(a):
    global testt 
    if testt == 1:
        testt= a
resp(2)
print (testt)

# %%
def ress(a):
    seee = 5
    return seee
print(ress(1))

# %%
invent = [1,2,3]
strr = (invent, 'a')
input(strr)

# %%
leve = 1
def penn(a):
    glo

# %%
lisst = ['']
day = 'red'
lisst.append(day)
print(lisst)
print(day)

# %%
a = boytalk0b = "Go away, I don't want to talk to you"
b = boytalk1b = "Dang yo, you're so annoying! What the heck do you want?"
c = boytalk2b = "Bro no way! I'm not giving you this gold for anything...well almost anything, but still, you're not geting this gold"
d = boytalk3b = "Whoa, you have a cake? I'll give you my peice of gold for that cake"
f = boytalk4a = "Alright, I gave you the gold, now go away so I can enjoy my cake"

boylist = [a,s,d,f,g]
boyresponsedict = {}
for i in range(0,5):
    boyresponsedict[i] = boylist[i]
print (boyresponsedict)

# %%
    



def response(person):
    if person == 'fatboy':
        if level == 1:
if 1 == 1:
    print(1)

# %%
butts = 'ggg',ggg
ggg  = 'ss'
print (butts)

# %%
a = 1
c = a
a = 2
c

# %%
if 1 == 1 and 2 == 2:
    print('aaa')

# %%
ppp = 'ddd'
print("james", ppp,"jjj")

# %%
balk = 'ffff'
vvv = balk + 'ffffff'
print (vvv)

# %%
ggg = ['ddd']
ggg = ['ccc']
ggg
# Out:
# ['ccc']

# %%
dictt = {}
dictt [1] = '2'
dictt
# Out:
# {1: '2'}
